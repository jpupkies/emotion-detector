# %% [markdown]
# <a href="https://colab.research.google.com/github/jpupkies/emotion-detector/blob/main/2a_Emotion_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 2a_Emotion_Detection.py

import requests

def emotion_detector(text_to_analyze):
    """
    Sends text to IBM Watson Natural Language Understanding API
    and returns the detected emotions with a dominant emotion.
    """

    # Watson NLU API endpoint and credentials
    url = "https://api.us-south.natural-language-understanding.watson.cloud.ibm.com/instances/YOUR_INSTANCE_ID/v1/analyze?version=2021-08-01"
    auth = ("apikey", "YOUR_API_KEY")  # Replace YOUR_API_KEY with your Watson NLU API key

    headers = {"Content-Type": "application/json"}

    data = {
        "text": text_to_analyze,
        "features": {
            "emotion": {}
        }
    }

    response = requests.post(url, json=data, headers=headers, auth=auth)

    if response.status_code == 200:
        emotions = response.json()["emotion"]["document"]["emotion"]
        dominant_emotion = max(emotions, key=emotions.get)
        return {
            "anger": emotions["anger"],
            "disgust": emotions["disgust"],
            "fear": emotions["fear"],
            "joy": emotions["joy"],
            "sadness": emotions["sadness"],
            "dominant_emotion": dominant_emotion
        }
    else:
        return {"error": f"API request failed with status code {response.status_code}"}


# Example usage (for testing locally)
if __name__ == "__main__":
    text = "I am thrilled about this amazing opportunity!"
    result = emotion_detector(text)
    print(result)
# Out:
# {'error': 'API request failed with status code 401'}
